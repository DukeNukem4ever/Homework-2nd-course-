# %%
import urllib.request
import re
import os
equal = []

# %%
import csv

if not os.path.exists('proektu/plain/2018'):
    os.makedirs('proektu/plain/2018')
            
if not os.path.exists('proektu/mystem-plain/2018'):
    os.makedirs('proektu/mystem-plain/2018')
            
if not os.path.exists('proektu/mystem-xml/2018'):
    os.makedirs('proektu/mystem-xml/2018')

csv_file = open('proektu/metadata90.csv', mode='w',encoding="utf-8")
fieldnames = ['path','author','sex','birthday','header',
              'created','sphere','genre_fi','type','topic',
              'chronotop','style','audience_age','audience_level',
              'audience_level','audience_size','source','publication',
              'publisher','publ_year','medium','country','region','language']
writer = csv.DictWriter(csv_file, fieldnames=fieldnames, delimiter='\t')
writer.writeheader()

# Чтобы значения выводились в табличку, программу нужно запускать дважды.

def download_page(pageUrl):
    try:
        page = urllib.request.urlopen(pageUrl)
        text = page.read().decode('utf-8')
        regPostTitle = re.compile(r'(<title>.*?)/', flags= re.DOTALL)
        titles = regPostTitle.findall(text)
        new_titles = []
        regTag = re.compile('<.*?>', re.DOTALL)
        regSpace = re.compile('\s{2,}', re.DOTALL)
        for t in titles:
            clean_t = regSpace.sub("", t)
            clean_t = regTag.sub("", clean_t)
            new_titles.append(clean_t)
        for t in new_titles:
            t = t.replace(' ','_')
            equal.append(t)
            if t not in equal:
                print('@ti ', t)
            
        regPostTitleAuthor = re.compile(r'</p><p align="right">.*?</p>|</strong></span></p><p align="right"><span style="font-size: small;"><strong>.*?</strong></span></p><div class="source"> <a href|right;" align="right"><span style="font-size: small;"><strong>.*?</strong></span></p><p style="text-align: right;"|;.</p><p>.*?</p></div></div></ul></div><div class="block">|&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <strong>&nbsp;&nbsp;*?</strong></span></p><p style="text-align: right;"><span style="font-size: small;"><strong>', flags= re.DOTALL)
        author = regPostTitleAuthor.findall(text)
        new_author = []
        regTag1 = re.compile('<.*?>', re.DOTALL)
        regSpace1 = re.compile('\s{2,}', re.DOTALL)
        regDescr1 = re.compile('Автор: ', re.DOTALL)
        for aa in author:
            clean_a = regSpace1.sub("", aa)
            clean_a = regTag1.sub("", clean_a)
            clean_a = regDescr1.sub("", clean_a)
            new_author.append(clean_a)

        if new_author:
            global a
            for a in new_author:
                if a != "&nbsp;":
                    print('@au ',a.replace('&nbsp;','').replace('&laquo;', '"').replace('&raquo;', '"').replace('right;" align="right">','').replace('<p style="text-align: right;"','').replace(';.',''))
        else:
            print('@au ', 'None')
            
        regPostTitleDate = re.compile(r'"date">....*?</span>|<div class="meta....*?</div>|<span class="date">....*?</span>', flags = re.DOTALL)#'|_start\'>....*?</span>', flags = re.DOTALL)
        date = regPostTitleDate.findall(text)
        new_date = []
        regTag3 = re.compile('<.*?>', re.DOTALL)
        regSpace3 = re.compile('\s{2,}', re.DOTALL)
        for d in date:
            clean_d = regSpace3.sub("", d)
            clean_d = regTag3.sub("", clean_d)
            new_date.append(clean_d)
        for d in new_date:
            if d != "&nbsp;":
                d = d.replace('"date">', '').replace('_start\'>', '').replace('<div class="meta">', '').replace('<span class="date"','')
                print('@da ', d)
        
        regPostTitleTopic = re.compile(r'href=\'?module=news&amp;action=list&amp;rubnews=37&amp;id=0\'class=\'link_name\'><span class=\'h_2 name\'>.*?</span></a>',flags = re.DOTALL)
        topic = regPostTitleTopic.findall(text)
        new_topic = []
        regTag7 = re.compile('<.*?>', re.DOTALL)
        regSpace7 = re.compile('\s{2,}', re.DOTALL)
        for t in topic:
            clean_t = regSpace7.sub("", t)
            clean_t = regTag7.sub("", clean_t)
            new_topic.append(clean_t).replace(' ','_')
        if new_topic:
            for t in new_topic:
                if t != "&nbsp;":
                    print('@topic ',t.replace('<div class="meta">', ''))
        else:
            print('@topic None')
        
        regPostcontent = re.compile(r'class="full-img" /><p><strong>.*?</span></p><p style="text-align: right;" align="right">|class="full-img" /><p><strong>.*?</p><p align="right">&nbsp;</p><p align="right">|class="full-img" alt="" /><div class="full-news-intro"></div><div class="full-text"><p>.*?</p></div></div></ul></div><div class="block"><div class="yashare-auto-init"|class="full-img" /><p><strong>.*?</span></p><p align="right"><span style="font-size: small;"><strong>|class="full-img" /><p><strong>.*?</span></p><p align="right"><strong><span style="font-size: small;">|class="full-img" /><p><strong>.*?</p><p style="text-align: justify;">&nbsp;</p><p style="text-align: right;" align="right">|class="full-img".*?<br /><br /></span></p><div style="text-align: right;"><span style="font-size: small;"><strong>|class="full-img" /><p><strong>.*?</span></p><p style="text-align: right;"><span style="font-size: small;">|<span style="font-size: small;"><strong>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*?</strong></span></p><p>&nbsp;</p><p><strong>&nbsp;</strong></p><div class="source">', flags= re.DOTALL)
        content = regPostcontent.findall(text)
        new_content = []
        regTag8 = re.compile('<.*?>', re.DOTALL)
        regSpace8 = re.compile('\s{2,}', re.DOTALL)
        regDescr8 = re.compile('Автор:', re.DOTALL)
        for c in content:
            clean_c8 = regSpace8.sub("", c)
            clean_c8 = regTag8.sub("", clean_c8)
            clean_c8 = regDescr8.sub("", clean_c8)
            new_content.append(clean_c8)
        #for c in new_content:
        #    print(c.replace('<div class="yashare-auto-init"','').replace('&hellip;','').replace('&mdash;', '–').replace('&ndash;',' ').replace('class="full-img" />','').replace('class="full-img" alt="" />','').replace('&laquo;','\"').replace('&raquo;','\"').replace("&nbsp;", " "))

        writer.writerow({'path': 'proektu/plain/2018/%s/info.txt' % t, 'author': a.replace('&nbsp;','').replace(
            '&laquo;', '"').replace('&raquo;', '"').replace('right;" align="right">','').replace(
            '<p style="text-align: right;"','').replace(
            ';.',''), 'sex': ' ','birthday': ' ', 'header': t, 'created': d.replace('<div class="meta">', ''), 'sphere': 'Публицистика', 'genre_fi': ' ',
                         'type': ' ', 'topic': t, 'chronotop': ' ', 'style': 'нейтральный', 'audience_age': 'н-возраст',
                         'audience_level': 'н-уровень', 'audience_size': 'районная', 'source': 'http://urogay-smol.ru/',
                         'publication': 'За урожай', 'publisher': ' ', 'publ_year': d[0:4], 'medium': 'газета', 'country': 'Россия',
                         'region': 'Смоленская область', 'language': 'ru'})
        
        if not os.path.exists('proektu/plain/2018/%s' % t):
            os.makedirs('proektu/plain/2018/%s' % t)
        
        if not os.path.exists('proektu/mystem-plain/2018/%s' % t):
            os.makedirs('proektu/mystem-plain/2018/%s' % t)
        
        if not os.path.exists('proektu/mystem-xml/2018/%s' % t):
            os.makedirs('proektu/mystem-xml/2018/%s' % t)
        
        #if not os.path.exists('proektu/texts/%s' % t):
        #    os.makedirs('proektu/texts/%s' % t)
        
        f = open('proektu/plain/2018/%s/info.txt' % t, "w", encoding="utf-8")
        #d = open('proektu/%s.txt' % t, 'w', encoding = "utf-8")
        m = open('proektu/overall12.txt', 'a', encoding = "utf-8")
        
        for t in new_titles:
            t = t.replace(' ','_')
            #if t not in equal:
            f.write('@ti ')
            f.write(t)
            f.write('\n')
            
        if new_author:
            for a in new_author:
                if a != "&nbsp;":
                    f.write('@au ')
                    a2 = a.replace('&nbsp;','').replace('&laquo;', '"').replace('&raquo;', '"').replace('right;" align="right">','').replace('<p style="text-align: right;"','').replace(';.','')
                    f.write(a2)
                    f.write('\n')
        else:
            f.write('@au None')
            f.write('\n')
            
        #if new_author:
        #    for a in new_author:
        #        if a != "&nbsp;":
                
            
        for c in new_content:
            f.write(c.replace('&hellip;','').replace('&ndash;',' ').replace('class="full-img" alt="" />','').replace('&mdash;', '--').replace("&nbsp;", " ").replace('class="full-img" />','').replace('&laquo;','\"').replace('&raquo;','\"'))
            f.write('\n')
            #m.write('\n')
            #d.write(c.replace('&hellip;','').replace('&ndash;',' ').replace('class="full-img" alt="" />','').replace('&mdash;', '--').replace("&nbsp;", " ").replace('class="full-img" />','').replace('&laquo;','\"').replace('&raquo;','\"'))
            #d.write('\n')
            #m.write('\n')
            #m.write(c.replace('&hellip;','').replace('&ndash;',' ').replace('class="full-img" alt="" />','').replace('&mdash;', '--').replace("&nbsp;", " ").replace('class="full-img" />','').replace('&laquo;','\"').replace('&raquo;','\"'))
            #m.write('\n')
            #m = open('proektu/text1.txt', 'a', encoding = 'utf-8')
            #m.write(c.replace('&hellip;','').replace('&ndash;',' ').replace('class="full-img" alt="" />','').replace('&mdash;', '--').replace("&nbsp;", " ").replace('class="full-img" />','').replace('&laquo;','\"').replace('&raquo;','\"'))
            #m.write('\n')
            #m.write('\n')
            os.system("mystem.exe -cgid proektu/overall12.txt proektu/overall12_mystem.txt")
            os.system("mystem.exe -cgid --format xml proektu/overall12.txt proektu/overall12_mystem.xml")
            #p = open('proektu/overall12_mystem.txt', 'r', encoding = 'utf-8')
            #p2 = open('proektu/overall12_mystem.xml', 'r', encoding = 'utf-8')
            #res = open('proektu/mystem-plain/2018/%s/overall12_mystem.txt' % t, 'w', encoding = 'utf-8')
            #res2 = open('proektu/mystem-xml/2018/%s/overall12_mystem.xml' % t, 'w', encoding = 'utf-8')
            #i = re.findall('\n', p.read())
            #i2 = re.findall('\n', p2.read())
            #res.write(str(i))
            #res2.write(str(i2))
            
        for d in new_date:
            if d != "&nbsp;":
                d = d.replace('"date">', '').replace('_start\'>', '').replace('<div class="meta">', '').replace('<span class="date"','')
                f.write('@da ')
                f.write(d)
                f.write('\n')
        if new_topic:
            for t in new_topic:
                if t != "&nbsp;":
                    f.write('@topic ')
                    f.write(t.replace('<div class="meta">', '').replace('<div class="yashare-auto-init"',''))
        else:
            f.write('@topic None')
            f.write('\n')
            # '
        os.system("mystem.exe -cgid proektu/plain/2018/%s/info.txt proektu/mystem-plain/2018/%s/info.txt" % (t, t))
        os.system("mystem.exe -cgid --format xml proektu/plain/2018/%s/info.txt proektu/mystem-plain/2018/%s/info.xml")
        
    except Exception as e:
        print(str(e))
    return

commonUrl = 'http://urogay-smol.ru/'
